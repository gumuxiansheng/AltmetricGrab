# %%
import codecs
import urllib
import re
from bs4 import BeautifulSoup

# %%
import requests

url = "https://moodle.kent.ac.uk/2018/course/view.php"

querystring = {"id":"1897"}

headers = {
    'accept': "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    'accept-language': "zh-CN,zh;q=0.9",
    'content-type': 'charset=utf8',
    'cache-control': "max-age=0,no-cache",
    'cookie': "MoodleSession=bh95cb0r5mvqc0n5nl2311qats; optimizelyEndUserId=oeu1576805091684r0.5280257672419764; optimizelySegments=%7B%22700332969%22%3A%22direct%22%2C%22703200875%22%3A%22false%22%2C%22704334772%22%3A%22gc%22%7D; optimizelyBuckets=%7B%7D; _gcl_au=1.1.91719409.1576805122; _hjid=ad8026ec-1d07-4d45-bc5d-b0c8aa8841c1; _ga=GA1.3.1786459308.1576832247; _gid=GA1.3.513631601.1578463709; SimpleSAMLSessionID=6483bd5fd8c73982c3b093254944a047; SimpleSAMLAuthToken=_3a333e41370c3949bb7f9b39d29533a891b3a8eb91; _gat_kbtracker=1; _gat_kentmoodle=1",
    'referer': "https://sso.id.kent.ac.uk/idp/saml2/idp/SSOService.php?SAMLRequest=fVJbT8IwFP4rS993BWFrxhKUGElQCZs%2B%2BEK6rpOGrZ09rdF%2FbykY8WVvzXe%2BW09ODqTvBrw0%2BiB27MMw0N5X3wnAbrBARgksCXDAgvQMsKa4XD5ucBJEeFBSSyo7dCUZVxAApjSXAnnr1QLts1k7ZfN0Oo3nk5s4qtN63kZ1lqURSVg8S%2BksodmE1aRF3itTYJULZI2sHMCwtQBNhLZQFGd%2BnPhJXMURTiI8Sd%2BQt7K%2F4YJopzpoPQAOQwAZ8CY4MqEDQgNzDHkzhKfqiXuV5XPJ1CenLBgOA%2FKWv5XvpADTM3WZvuw2f6a9lE3Hrk33MFi0MZ2zcf4hXHJ8QsGhDWuJ6bQPNmd7WeYtFw0X7%2BN7rM8kwA9VtfW3z2WFivzkjd1eVDFaLA%2Bvqfn5BJ5syHq1lR2n3969VD3R4x1OCG%2F81lGxVkQAtzEoLM7%2B%2F6%2Bq%2BAE%3D&RelayState=https%3A%2F%2Fmoodle.kent.ac.uk%2F2019%2Fcourse%2Fview.php%3Fid%3D4879",
    'sec-fetch-mode': "navigate",
    'sec-fetch-site': "same-site",
    'upgrade-insecure-requests': "1",
    'user-agent': "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.70 Safari/537.36",
    'Host': "moodle.kent.ac.uk",
    'Connection': "keep-alive"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# span data-region="dialogue-button-text">Send contact request</span>
#                         <span class="hidden" data-region="loading-icon-container"><span class="loading-icon icon-no-margin"><i class="icon fa fa-circle-o-notch fa-spin fa-fw "  title="Loading" aria-label="Loading"></i></span>
# </span>
#                     </button>
#                 </div>
#             </div>
#             <div class="hidden bg-secondary p-3" data-region="content-messages-footer-require-unblock-container">
#
#                 <div class="p-3 bg-white">
#                     <p class="text-muted" data-region="text">You have blocked this user.</p>
#                     <button type="button" class="btn btn-primary btn-block" data-action="request-unblock">
#                         <span data-region="dialogue-button-text">Unblock user</span>
# ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')
hrefs = soup.find_all('a', href=re.compile('https://moodle.kent.ac.uk/2018/mod/resource'))

start_index = 0

for a in hrefs:
    acc = a.find('span', attrs={'class':'accesshide'})
    if (acc != None) and (acc.string.strip() == 'File'):
        url = a['href']
        res_file = requests.request("GET", url, headers=headers, allow_redirects=False)
        url = res_file.headers.get('Location')
        res_file = requests.request("GET", url, headers=headers)
        print(url)
        start = res_file.headers['Content-Disposition'].find('filename=')
        file_name = res_file.headers['Content-Disposition'][start+len('filename="'):-1]
        with codecs.open('Kent_1897/' + file_name, "wb+", errors='ignore') as f:
            f.write(res_file.content)
# Out:
# https://moodle.kent.ac.uk/2018/pluginfile.php/401868/mod_resource/content/0/CB8023-Module%20Guide%202018-19.pdf
# https://moodle.kent.ac.uk/2018/pluginfile.php/339361/mod_resource/content/0/CB8023_Assignment%20I_2018.pdf
# https://moodle.kent.ac.uk/2018/pluginfile.php/248493/mod_resource/content/1/Peer%20Assessment%20Form%20%28CB8023%29.docx
# https://moodle.kent.ac.uk/2018/pluginfile.php/248494/mod_resource/content/1/Slides%20Preparation%20Guidelines-Assignment%20I.pptx
# https://moodle.kent.ac.uk/2018/pluginfile.php/248495/mod_resource/content/1/PGT%20Presentation%20Categorical%20Marking.docx
# https://moodle.kent.ac.uk/2018/pluginfile.php/339376/mod_resource/content/0/PGT%20Report-Essay%20Categorical%20Marking.docx
# https://moodle.kent.ac.uk/2018/pluginfile.php/401869/mod_resource/content/0/CB8023%20Assignment%20III-Report.pdf
# https://moodle.kent.ac.uk/2018/pluginfile.php/248491/mod_resource/content/2/Input-Output%20Table%20Questions%203%20and%204.xlsx
# ...

# %%
hrefs
# Out:
# [<a class="" href="https://moodle.kent.ac.uk/2018/mod/resource/view.php?id=338531" onclick=""><img alt="" aria-hidden="true" class="iconlarge activityicon" role="presentation" src="https://moodle.kent.ac.uk/2018/theme/image.php/kentb/core/1578386140/f/pdf-24"/><span class="instancename">CB8023-Module Guide 2018-19<span class="accesshide"> File</span></span></a>,
#  <a class="" href="https://moodle.kent.ac.uk/2018/mod/resource/view.php?id=278209" onclick=""><img alt="" aria-hidden="true" class="iconlarge activityicon" role="presentation" src="https://moodle.kent.ac.uk/2018/theme/image.php/kentb/core/1578386140/f/pdf-24"/><span class="instancename">CB8023 Assignment I<span class="accesshide"> File</span></span></a>,
# ...
